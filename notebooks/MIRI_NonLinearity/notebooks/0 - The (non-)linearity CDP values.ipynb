# %% [markdown]
# # The (non-)linearity CDP values

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.

# %%
# import modules
import funcs
import mrsobs

import numpy as np
from astropy.io import fits
from matplotlib import pyplot as plt
plt.style.use('presentation')
# %matplotlib notebook

import warnings
warnings.simplefilter('ignore')

# %%
bands = ["1A", "1B", "1C", "2A", "2B", "2C", "3A", "3B", "3C", "4A", "4B", "4C"]

# %%
# Define paths to data
workDir   = '/Users/ioannisa/Desktop/python/miri_devel/'
cdpDir    = workDir+'cdp_data/'

# %%
# all linearity CDPs

linearity_files = ['MIRI_FM_RAL_MIRIFUSHORT_12_LINEARITY_07.02.00.fits',
                   'MIRI_FM_RAL_MIRIFULONG_34MEDIUM_LINEARITY_07.02.00.fits',
                   'MIRI_FM_RAL_MIRIFULONG_34MEDIUM_LINEARITY_06.02.00.fits',
                   'MIRI_FM_MIRIFUSHORT_12_LINEARITY_06.02.00.fits',
                   'MIRI_FM_MIRIFULONG_34SHORT_LINEARITY_06.02.00.fits',
                   'MIRI_FM_MIRIFULONG_34MEDIUM_LINEARITY_06.02.00.fits',
                   'MIRI_FM_MIRIFULONG_34LONG_LINEARITY_06.02.00.fits']
# Out:
# 'MIRI_FM_MIRIFULONG_34LONG_LINEARITY_06.02.00.fits'

# %%
linearityCorrection0 = fits.open(cdpDir+'MIRI_FM_MIRIFUSHORT_12_LINEARITY_06.02.00.fits')[1].data
linearityCorrection1 = fits.open(cdpDir+'MIRI_FM_RAL_MIRIFUSHORT_12_LINEARITY_07.02.00.fits')[1].data

# # two columns of plots
# fig,axs = plt.subplots(5,2,figsize=(12,25))
# for plot in range(5):
#     if plot == 0:
#         axs[plot,0].imshow(linearityCorrection0[plot,:,:])
#         axs[plot,1].imshow(linearityCorrection1[plot,:,:])
#     else:
#         axs[plot,0].imshow(linearityCorrection0[plot,:,:],vmin=np.min(linearityCorrection0[plot,:,:][np.nonzero(linearityCorrection0[plot,:,:])]),vmax=np.max(linearityCorrection0[plot,:,:][np.nonzero(linearityCorrection0[plot,:,:])]))
#         axs[plot,1].imshow(linearityCorrection1[plot,:,:],vmin=np.min(linearityCorrection1[plot,:,:][np.nonzero(linearityCorrection1[plot,:,:])]),vmax=np.max(linearityCorrection1[plot,:,:][np.nonzero(linearityCorrection1[plot,:,:])]))
#     axs[plot,0].set_xlabel('X-pixel');axs[plot,1].set_xlabel('X-pixel')
#     axs[plot,0].set_ylabel('Y-pixel');axs[plot,1].set_ylabel('Y-pixel')
#     if plot in [0,1]:
#         axs[plot,0].set_title('L$_{}$ = {} / {} (old)'.format(plot,round(linearityCorrection0[plot,512,100],3),round(linearityCorrection0[plot,512,600],3)))
#         axs[plot,1].set_title('L$_{}$ = {} / {} (new)'.format(plot,round(linearityCorrection1[plot,512,100],3),round(linearityCorrection1[plot,512,600],3)))
#     else:
#         axs[plot,0].set_title('L$_{}$ = {} / {} (old)'.format(plot,str(linearityCorrection0[plot,512,100])[:4]+str(linearityCorrection0[plot,512,100])[-4:],str(linearityCorrection0[plot,512,600])[:4]+str(linearityCorrection0[plot,512,600])[-4:]))
#         axs[plot,1].set_title('L$_{}$ = {} / {} (new)'.format(plot,str(linearityCorrection1[plot,512,100])[:4]+str(linearityCorrection1[plot,512,100])[-4:],str(linearityCorrection1[plot,512,600])[:4]+str(linearityCorrection1[plot,512,600])[-4:]))
# plt.tight_layout()

# two rows of plots
fig,axs = plt.subplots(2,5,figsize=(25,8))
for plot in range(5):
    if plot == 0:
        axs[0,plot].imshow(linearityCorrection0[plot,:,:])
        axs[1,plot].imshow(linearityCorrection1[plot,:,:])
    else:
        axs[0,plot].imshow(linearityCorrection0[plot,:,:],vmin=np.min(linearityCorrection0[plot,:,:][np.nonzero(linearityCorrection0[plot,:,:])]),vmax=np.max(linearityCorrection0[plot,:,:][np.nonzero(linearityCorrection0[plot,:,:])]))
        axs[1,plot].imshow(linearityCorrection1[plot,:,:],vmin=np.min(linearityCorrection1[plot,:,:][np.nonzero(linearityCorrection1[plot,:,:])]),vmax=np.max(linearityCorrection1[plot,:,:][np.nonzero(linearityCorrection1[plot,:,:])]))
    axs[0,plot].set_xlabel('X-pixel');axs[1,plot].set_xlabel('X-pixel')
    axs[0,plot].set_ylabel('Y-pixel');axs[1,plot].set_ylabel('Y-pixel')
    if plot in [0,1]:
        axs[0,plot].set_title('L$_{}$ = {} / {} (old)'.format(plot,round(linearityCorrection0[plot,512,100],3),round(linearityCorrection0[plot,512,600],3)))
        axs[1,plot].set_title('L$_{}$ = {} / {} (new)'.format(plot,round(linearityCorrection1[plot,512,100],3),round(linearityCorrection1[plot,512,600],3)))
    else:
        axs[0,plot].set_title('L$_{}$ = {} / {} (old)'.format(plot,str(linearityCorrection0[plot,512,100])[:4]+str(linearityCorrection0[plot,512,100])[-4:],str(linearityCorrection0[plot,512,600])[:4]+str(linearityCorrection0[plot,512,600])[-4:]))
        axs[1,plot].set_title('L$_{}$ = {} / {} (new)'.format(plot,str(linearityCorrection1[plot,512,100])[:4]+str(linearityCorrection1[plot,512,100])[-4:],str(linearityCorrection1[plot,512,600])[:4]+str(linearityCorrection1[plot,512,600])[-4:]))
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="2500">

# %%
linearityCorrection0 = fits.open(cdpDir+'MIRI_FM_RAL_MIRIFULONG_34MEDIUM_LINEARITY_06.02.00.fits')[1].data
linearityCorrection1 = fits.open(cdpDir+'MIRI_FM_RAL_MIRIFULONG_34MEDIUM_LINEARITY_07.02.00.fits')[1].data

# # two columns of plots
# fig,axs = plt.subplots(5,2,figsize=(12,25))
# for plot in range(5):
#     if plot == 0:
#         axs[plot,0].imshow(linearityCorrection0[plot,:,:])
#         axs[plot,1].imshow(linearityCorrection1[plot,:,:])
#     else:
#         axs[plot,0].imshow(linearityCorrection0[plot,:,:],vmin=np.min(linearityCorrection0[plot,:,:][np.nonzero(linearityCorrection0[plot,:,:])]),vmax=np.max(linearityCorrection0[plot,:,:][np.nonzero(linearityCorrection0[plot,:,:])]))
#         axs[plot,1].imshow(linearityCorrection1[plot,:,:],vmin=np.min(linearityCorrection1[plot,:,:][np.nonzero(linearityCorrection1[plot,:,:])]),vmax=np.max(linearityCorrection1[plot,:,:][np.nonzero(linearityCorrection1[plot,:,:])]))
#     axs[plot,0].set_xlabel('X-pixel');axs[plot,1].set_xlabel('X-pixel')
#     axs[plot,0].set_ylabel('Y-pixel');axs[plot,1].set_ylabel('Y-pixel')
#     if plot in [0,1]:
#         axs[plot,0].set_title('L$_{}$ = {} / {} (old)'.format(plot,round(linearityCorrection0[plot,512,100],3),round(linearityCorrection0[plot,512,600],3)))
#         axs[plot,1].set_title('L$_{}$ = {} / {} (new)'.format(plot,round(linearityCorrection1[plot,512,100],3),round(linearityCorrection1[plot,512,600],3)))
#     else:
#         axs[plot,0].set_title('L$_{}$ = {} / {} (old)'.format(plot,str(linearityCorrection0[plot,512,100])[:4]+str(linearityCorrection0[plot,512,100])[-4:],str(linearityCorrection0[plot,512,600])[:4]+str(linearityCorrection0[plot,512,600])[-4:]))
#         axs[plot,1].set_title('L$_{}$ = {} / {} (new)'.format(plot,str(linearityCorrection1[plot,512,100])[:4]+str(linearityCorrection1[plot,512,100])[-4:],str(linearityCorrection1[plot,512,600])[:4]+str(linearityCorrection1[plot,512,600])[-4:]))
# plt.tight_layout()

# two rows of plots
fig,axs = plt.subplots(2,5,figsize=(25,8))
for plot in range(5):
    if plot == 0:
        axs[0,plot].imshow(linearityCorrection0[plot,:,:])
        axs[1,plot].imshow(linearityCorrection1[plot,:,:])
    else:
        axs[0,plot].imshow(linearityCorrection0[plot,:,:],vmin=np.min(linearityCorrection0[plot,:,:][np.nonzero(linearityCorrection0[plot,:,:])]),vmax=np.max(linearityCorrection0[plot,:,:][np.nonzero(linearityCorrection0[plot,:,:])]))
        axs[1,plot].imshow(linearityCorrection1[plot,:,:],vmin=np.min(linearityCorrection1[plot,:,:][np.nonzero(linearityCorrection1[plot,:,:])]),vmax=np.max(linearityCorrection1[plot,:,:][np.nonzero(linearityCorrection1[plot,:,:])]))
    axs[0,plot].set_xlabel('X-pixel');axs[1,plot].set_xlabel('X-pixel')
    axs[0,plot].set_ylabel('Y-pixel');axs[1,plot].set_ylabel('Y-pixel')
    if plot in [0,1]:
        axs[0,plot].set_title('L$_{}$ = {} / {} (old)'.format(plot,round(linearityCorrection0[plot,512,100],3),round(linearityCorrection0[plot,512,600],3)))
        axs[1,plot].set_title('L$_{}$ = {} / {} (new)'.format(plot,round(linearityCorrection1[plot,512,100],3),round(linearityCorrection1[plot,512,600],3)))
    else:
        axs[0,plot].set_title('L$_{}$ = {} / {} (old)'.format(plot,str(linearityCorrection0[plot,512,100])[:4]+str(linearityCorrection0[plot,512,100])[-4:],str(linearityCorrection0[plot,512,600])[:4]+str(linearityCorrection0[plot,512,600])[-4:]))
        axs[1,plot].set_title('L$_{}$ = {} / {} (new)'.format(plot,str(linearityCorrection1[plot,512,100])[:4]+str(linearityCorrection1[plot,512,100])[-4:],str(linearityCorrection1[plot,512,600])[:4]+str(linearityCorrection1[plot,512,600])[-4:]))
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="2500">

# %%
linearityCorrection0 = fits.open(cdpDir+'MIRI_FM_MIRIFULONG_34SHORT_LINEARITY_06.02.00.fits')[1].data
linearityCorrection1 = fits.open(cdpDir+'MIRI_FM_MIRIFULONG_34MEDIUM_LINEARITY_06.02.00.fits')[1].data
linearityCorrection2 = fits.open(cdpDir+'MIRI_FM_MIRIFULONG_34LONG_LINEARITY_06.02.00.fits')[1].data

# # three columns of plots
# fig,axs = plt.subplots(5,3,figsize=(18,25))
# for plot in range(5):
#     if plot == 0:
#         axs[plot,0].imshow(linearityCorrection0[plot,:,:])
#         axs[plot,1].imshow(linearityCorrection1[plot,:,:])
#         axs[plot,2].imshow(linearityCorrection2[plot,:,:])
#     else:
#         axs[plot,0].imshow(linearityCorrection0[plot,:,:],vmin=np.min(linearityCorrection0[plot,:,:][np.nonzero(linearityCorrection0[plot,:,:])]),vmax=np.max(linearityCorrection0[plot,:,:][np.nonzero(linearityCorrection0[plot,:,:])]))
#         axs[plot,1].imshow(linearityCorrection1[plot,:,:],vmin=np.min(linearityCorrection1[plot,:,:][np.nonzero(linearityCorrection1[plot,:,:])]),vmax=np.max(linearityCorrection1[plot,:,:][np.nonzero(linearityCorrection1[plot,:,:])]))
#         axs[plot,2].imshow(linearityCorrection2[plot,:,:],vmin=np.min(linearityCorrection2[plot,:,:][np.nonzero(linearityCorrection2[plot,:,:])]),vmax=np.max(linearityCorrection2[plot,:,:][np.nonzero(linearityCorrection2[plot,:,:])]))
#     axs[plot,0].set_xlabel('X-pixel');axs[plot,1].set_xlabel('X-pixel');axs[plot,2].set_xlabel('X-pixel')
#     axs[plot,0].set_ylabel('Y-pixel');axs[plot,1].set_ylabel('Y-pixel');axs[plot,2].set_ylabel('Y-pixel')
#     if plot in [0,1]:
#         axs[plot,0].set_title('L$_{}$ = {} / {} (SHORT)'.format(plot,round(linearityCorrection0[plot,512,100],3),round(linearityCorrection0[plot,512,600],3)))
#         axs[plot,1].set_title('L$_{}$ = {} / {} (MEDIUM)'.format(plot,round(linearityCorrection1[plot,512,100],3),round(linearityCorrection1[plot,512,600],3)))
#         axs[plot,2].set_title('L$_{}$ = {} / {} (LONG)'.format(plot,round(linearityCorrection2[plot,512,100],3),round(linearityCorrection2[plot,512,600],3)))
#     else:
#         axs[plot,0].set_title('L$_{}$ = {} / {} (SHORT)'.format(plot,str(linearityCorrection0[plot,512,100])[:4]+str(linearityCorrection0[plot,512,100])[-4:],str(linearityCorrection0[plot,512,600])[:4]+str(linearityCorrection0[plot,512,600])[-4:]))
#         axs[plot,1].set_title('L$_{}$ = {} / {} (MEDIUM)'.format(plot,str(linearityCorrection1[plot,512,100])[:4]+str(linearityCorrection1[plot,512,100])[-4:],str(linearityCorrection1[plot,512,600])[:4]+str(linearityCorrection1[plot,512,600])[-4:]))
#         axs[plot,2].set_title('L$_{}$ = {} / {} (LONG)'.format(plot,str(linearityCorrection2[plot,512,100])[:4]+str(linearityCorrection2[plot,512,100])[-4:],str(linearityCorrection2[plot,512,600])[:4]+str(linearityCorrection2[plot,512,600])[-4:]))
# plt.tight_layout()

# three rows of plots
fig,axs = plt.subplots(3,5,figsize=(25,12))
for plot in range(5):
    if plot == 0:
        axs[0,plot].imshow(linearityCorrection0[plot,:,:])
        axs[1,plot].imshow(linearityCorrection1[plot,:,:])
        axs[2,plot].imshow(linearityCorrection2[plot,:,:])
    else:
        axs[0,plot].imshow(linearityCorrection0[plot,:,:],vmin=np.min(linearityCorrection0[plot,:,:][np.nonzero(linearityCorrection0[plot,:,:])]),vmax=np.max(linearityCorrection0[plot,:,:][np.nonzero(linearityCorrection0[plot,:,:])]))
        axs[1,plot].imshow(linearityCorrection1[plot,:,:],vmin=np.min(linearityCorrection1[plot,:,:][np.nonzero(linearityCorrection1[plot,:,:])]),vmax=np.max(linearityCorrection1[plot,:,:][np.nonzero(linearityCorrection1[plot,:,:])]))
        axs[2,plot].imshow(linearityCorrection2[plot,:,:],vmin=np.min(linearityCorrection2[plot,:,:][np.nonzero(linearityCorrection2[plot,:,:])]),vmax=np.max(linearityCorrection2[plot,:,:][np.nonzero(linearityCorrection2[plot,:,:])]))
    axs[0,plot].set_xlabel('X-pixel');axs[1,plot].set_xlabel('X-pixel');axs[2,plot].set_xlabel('X-pixel')
    axs[0,plot].set_ylabel('Y-pixel');axs[1,plot].set_ylabel('Y-pixel');axs[2,plot].set_ylabel('Y-pixel')
    if plot in [0,1]:
        axs[0,plot].set_title('L$_{}$ = {} / {} (SHORT)'.format(plot,round(linearityCorrection0[plot,512,100],3),round(linearityCorrection0[plot,512,600],3)))
        axs[1,plot].set_title('L$_{}$ = {} / {} (MEDIUM)'.format(plot,round(linearityCorrection1[plot,512,100],3),round(linearityCorrection1[plot,512,600],3)))
        axs[2,plot].set_title('L$_{}$ = {} / {} (LONG)'.format(plot,round(linearityCorrection2[plot,512,100],3),round(linearityCorrection2[plot,512,600],3)))
    else:
        axs[0,plot].set_title('L$_{}$ = {} / {} (SHORT)'.format(plot,str(linearityCorrection0[plot,512,100])[:4]+str(linearityCorrection0[plot,512,100])[-4:],str(linearityCorrection0[plot,512,600])[:4]+str(linearityCorrection0[plot,512,600])[-4:]))
        axs[1,plot].set_title('L$_{}$ = {} / {} (MEDIUM)'.format(plot,str(linearityCorrection1[plot,512,100])[:4]+str(linearityCorrection1[plot,512,100])[-4:],str(linearityCorrection1[plot,512,600])[:4]+str(linearityCorrection1[plot,512,600])[-4:]))
        axs[2,plot].set_title('L$_{}$ = {} / {} (LONG)'.format(plot,str(linearityCorrection2[plot,512,100])[:4]+str(linearityCorrection2[plot,512,100])[-4:],str(linearityCorrection2[plot,512,600])[:4]+str(linearityCorrection2[plot,512,600])[-4:]))
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="2500">
