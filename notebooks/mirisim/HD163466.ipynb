# %%
# load python modules
import funcs
import mrsobs

import numpy as np
from astropy.io import fits
from matplotlib import pyplot as plt
plt.style.use('presentation')
# %matplotlib notebook

import warnings
warnings.simplefilter('ignore')

# %%
# Define paths to data
mirisim_dir = '/Users/ioannisa/Desktop/python/mirisim/'
workDir  = '/Users/ioannisa/Desktop/python/miri_devel/'
cdpDir   = workDir+'cdp_data/'
d2cMapDir = workDir+'notebooks/distortionMaps/'

# %%
file1 = mirisim_dir+'HD163466_band1A_4dither_fast_5frames_20int_mirisim_20181214_100254/det_images/det_image_seq1_MIRIFUSHORT_12SHORTexp1.fits'
file2 = mirisim_dir+'HD163466_band2A_4dither_fast_5frames_20int_mirisim_20181213_213003/det_images/det_image_seq1_MIRIFUSHORT_12SHORTexp1.fits'

image1 = fits.open(file1)[1].data[0,4,:,:]
image2 = fits.open(file2)[1].data[0,4,:,:]

# %%
plt.figure()
plt.imshow(image1)
plt.tight_layout()

plt.figure()
plt.imshow(image2)
plt.tight_layout()

plt.figure()
plt.plot(image1[512,:])
plt.plot(image2[512,:])
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
