# %%
import funcs
import mrsobs

import numpy as np
from matplotlib import pyplot as plt
plt.style.use('presentation')
# %matplotlib notebook

# %%
workDir = '/Users/ioannisa/Desktop/python/miri_devel/'

# %%
wav1,flux1 = np.genfromtxt('PHOENIX_GRIDS/lte058-4.5-0.0a+0.0.BT-NextGen.txt',usecols=(0,1),unpack=True)
wav2,flux2 = np.genfromtxt('PHOENIX_GRIDS/lte082-4.5-0.0a+0.0.BT-NextGen.txt',usecols=(0,1),unpack=True)
wav3,flux3 = np.genfromtxt('PHOENIX_GRIDS/lte094-4.5-0.0a+0.0.BT-NextGen.txt',usecols=(0,1),unpack=True)

# %%
plt.figure(figsize=(12,4))
plt.plot(wav1,flux1/1000.)
plt.plot(wav2,flux2/1000.)
plt.plot(wav3,flux3/1000.)
plt.vlines([4.83,5.82],0,3500,'k',linestyle='dashed')
plt.xlim(4.8,5.8)
plt.xlabel('Wavelength [micron]')
plt.ylabel('Flux [mJy]')
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1200">
